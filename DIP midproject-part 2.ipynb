# %%
import time

def TicTocGenerator():
    # Generator that returns time differences
    ti = 0           # initial time
    tf = time.time() # final time
    while True:
        ti = tf
        tf = time.time()
        yield tf-ti # returns the time difference

TicToc = TicTocGenerator() # create an instance of the TicTocGen generator

# This will be the main function through which we define both tic() and toc()
def toc(tempBool=True):
    # Prints the time difference yielded by generator instance TicToc
    tempTimeInterval = next(TicToc)
    if tempBool:
        print( "Elapsed time: %f seconds.\n" %tempTimeInterval )

def tic():
    # Records a time in TicToc, marks the beginning of a time interval
    toc(False)

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\nastya\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\nastya\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\nastya\anaconda3\lib\site-packages (9.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\nastya\anaconda3\lib\site-packages (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nastya\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\nastya\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\nastya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import scipy as sc
import numpy as np
from numpy import asarray
import requests
import csv
import cv2
import matplotlib.pyplot as plt
import scipy.ndimage
from PIL import Image

# %%
tic()
time.sleep(1)

toc()
# Out:
# Elapsed time: 1.010348 seconds.

# %% [markdown]
# # Filters

# %%
m_enh=np.zeros([3,3],dtype=int)
m_enh[1,1]= 5
m_enh[1,0]=-1
m_enh[1,2]=-1
m_enh[0,1]=-1
m_enh[2,1]=-1
print("Enhancement mask:")
print(m_enh)
# Out:
# Enhancement mask:
# [[ 0 -1  0]
#  [-1  5 -1]
#  [ 0 -1  0]]

# %%
m_smooth=np.ones([3,3])/9
print("Smoothing mask:")
print(m_smooth)
# Out:
# Smoothing mask:
# [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]

# %%
def imfilter(img,mask):
    r, c = mask.shape
    h, w = img.shape

    img_padded=np.pad(img, c-1, 'constant')
    img_masked=np.zeros([h+r+1,w+c+1],dtype=int)
    q=0
    # iterating trought padded matrix  
    for i in range(0,h+r-1):
        for j in range(0,w+c-1):
                # with r*c mask  
            for k in range(0,r):
                for l in range (0,c):
                    q=q+mask[k,l]*img_padded[i+k,j+l]
            img_masked[i+1,j+1]=q
            q=0
    img_unpadded=img_masked[r-1:h+r-1,c-1:w+c-1]
    return img_unpadded

# %% [markdown]
# # Tests

# %%
img2= cv2.imread('cat.jpeg',cv2.IMREAD_GRAYSCALE)
print(img2.shape)
# Out:
# (888, 888)

# %%
image2 = cv2.resize(img2, (256, 256)) 
cv2.imshow('image', image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
arr2 = np.asarray(image2)
print(arr2.shape)
# Out:
# (256, 256)

# %%
pl1=imfilter(arr2,m_smooth)

cv2.imwrite('s_img.jpg', pl1)
s_img= cv2.imread('s_img.jpg')
cv2.imshow('smoothed', s_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
pl2=imfilter(arr2,m_enh)

cv2.imwrite('enh_img.jpg', pl2)
enh_img= cv2.imread('enh_img.jpg')
cv2.imshow('enhanced', enh_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Lets compare to library function

# %%
lf1 = cv2.filter2D(image2,-1,m_smooth)

cv2.imwrite('lf1.jpg', lf1)
lft1= cv2.imread('lf1.jpg')

cv2.imshow('smoothed l.f.', lft1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
lf2 = cv2.filter2D(image2,-1,m_enh)

cv2.imwrite('lf2.jpg', lf2)
lft2= cv2.imread('lf2.jpg')
cv2.imshow('enhanced l.f.', lft2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
histogram, bin_edges = np.histogram(lft1, bins=256)

plt.figure()
plt.title("Smoothed by library filter")
plt.xlabel("grayscale value")
plt.ylabel("pixel count")
plt.plot(bin_edges[0:-1], histogram)

# %%
histogram, bin_edges = np.histogram(s_img, bins=256)

plt.figure()
plt.title("Smoothed by my filter")
plt.xlabel("grayscale value")
plt.ylabel("pixel count")
plt.plot(bin_edges[0:-1], histogram)

# %%
histogram, bin_edges = np.histogram(enh_img, bins=256)

plt.figure()
plt.title("Enhanced by my filter")
plt.xlabel("grayscale value")
plt.ylabel("pixel count")
plt.plot(bin_edges[0:-1], histogram)

# %%
histogram, bin_edges = np.histogram(lft2, bins=256)

plt.figure()
plt.title("Enhanced by library filter")
plt.xlabel("grayscale value")
plt.ylabel("pixel count")
plt.plot(bin_edges[0:-1], histogram)

# %%
m=lft1-s_img

cv2.imwrite('m.jpg', m)
m1= cv2.imread('m.jpg')
cv2.imshow('smoothing filters diffrence ', m)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(m, interpolation='nearest')
plt.show()

# %%
n=lft2-enh_img

cv2.imwrite('n.jpg', n)
n1= cv2.imread('n.jpg')
cv2.imshow('enhancement filters diffrence ', n)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(n, interpolation='nearest')
plt.show()
